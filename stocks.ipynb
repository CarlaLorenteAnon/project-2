# %% [markdown]
# This script takes historical stock data for H&M

# %%
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt

# %%
# https://www.nasdaq.com/market-activity/stocks/hnnmy/historical

stocks_df = pd.read_csv('Resources/stocks.csv')

stocks_df
# Out:
#             Date Close/Last  Volume    Open     High     Low
# 0     03/11/2022       $2.9   59913  $2.985   $2.985   $2.89
# 1     03/10/2022       $2.9  331788   $2.83    $2.96   $2.83
# 2     03/09/2022      $3.01  214160   $3.01  $3.0435   $2.97
# 3     03/08/2022      $2.79  838139   $2.71     $2.9    $2.7
# 4     03/07/2022      $2.61  651838   $2.78    $2.78   $2.59
# ...          ...        ...     ...     ...      ...     ...
# 1255  03/17/2017      $5.17   43622   $5.16    $5.19   $5.15
# 1256  03/16/2017       $5.2   95513    $5.2    $5.21  $5.164
# 1257  03/15/2017      $5.22   39114   $5.17    $5.25   $5.14
# 1258  03/14/2017      $5.44   52401   $5.43    $5.47   $5.43
# 1259  03/13/2017      $5.43   82163   $5.39    $5.45   $5.39
#
# [1260 rows x 6 columns]

# %%
# set start and end date

start_date = '09/19/2018'
start_date = dt.strptime(start_date, '%m/%d/%Y')

end_date = '09/21/2020'
end_date = dt.strptime(end_date, '%m/%d/%Y')

# %%
# filter dates to match transaction data

stocks_df = stocks_df[(stocks_df['Date'].apply(lambda x: dt.strptime(x, '%m/%d/%Y')) <= end_date) & 
        (stocks_df['Date'].apply(lambda x: dt.strptime(x, '%m/%d/%Y')) >= start_date)]
stocks_df
# Out:
#            Date Close/Last  Volume    Open   High    Low
# 371  09/21/2020     $3.335   59624   $3.39  $3.39  $3.31
# 372  09/18/2020      $3.55   14507  $3.533  $3.56  $3.52
# 373  09/17/2020     $3.587  123343  $3.564  $3.61  $3.55
# 374  09/16/2020      $3.59   59722   $3.61  $3.64  $3.56
# 375  09/15/2020      $3.52  154543   $3.57  $3.59  $3.52
# ..          ...        ...     ...     ...    ...    ...
# 871  09/25/2018      $3.31  227048   $3.31  $3.33  $3.29
# 872  09/24/2018      $3.33   82909   $3.34  $3.36  $3.32
# 873  09/21/2018     $3.245   89847   $3.22  $3.26  $3.22
# 874  09/20/2018       $3.2  233580   $3.18  $3.21  $3.17
# 875  09/19/2018     $3.135  104769   $3.13  $3.14  $3.12
#
# [505 rows x 6 columns]

# %%
stocks_df.plot(kind='line', x='Date');
